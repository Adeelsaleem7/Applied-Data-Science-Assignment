# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
dataset = pd.read_csv('dummy_data.csv')

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
# Understanding the dataset

# %%
dataset.head()
# Out:
#    age      gender  time_spent   platform  interests        location  \
# 0   56        male           3  Instagram     Sports  United Kingdom
# 1   46      female           2   Facebook     Travel  United Kingdom
# 2   32        male           8  Instagram     Sports       Australia
# 3   60  non-binary           5  Instagram     Travel  United Kingdom
# 4   25        male           1  Instagram  Lifestlye       Australia
#
#   demographics         profession  income  indebt  isHomeOwner  Owns_Car
# 0        Urban  Software Engineer   19774    True        False     False
# 1        Urban            Student   10564    True         True      True
# 2    Sub_Urban   Marketer Manager   13258   False        False     False
# 3        Urban            Student   12500   False         True     False
# 4        Urban  Software Engineer   14566   False         True      True

# %%
dataset.tail()
# Out:
#      age      gender  time_spent   platform  interests        location  \
# 995   22      female           8  Instagram  Lifestlye  United Kingdom
# 996   40  non-binary           6    YouTube     Travel  United Kingdom
# 997   27  non-binary           5    YouTube     Travel  United Kingdom
# 998   61      female           4    YouTube     Sports       Australia
# 999   19      female           8    YouTube     Travel       Australia
#
#     demographics         profession  income  indebt  isHomeOwner  Owns_Car
# 995        Rural   Marketer Manager   18536   False         True     False
# 996        Rural  Software Engineer   12711    True        False     False
# 997        Rural            Student   17595    True        False      True
# 998    Sub_Urban   Marketer Manager   16273    True         True     False
# 999        Rural            Student   16284   False         True     False

# %%
dataset.shape
# Out:
# (1000, 12)

# %%
print('Number of Columns',dataset.shape[0])
print('Number of Rows',dataset.shape[1]
# Out:
#   Cell In[10], line 2
#     print('Number of Rows',dataset.shape[1]
#                                            ^
# SyntaxError: incomplete input

# %%
print('Number of Columns',dataset.shape[0])
# Out:
# Number of Columns 1000

# %%
print('Number of Rows',dataset.shape[1])
# Out:
# Number of Rows 12

# %%
dataset.isnull().sum()
# Out:
# age             0
# gender          0
# time_spent      0
# platform        0
# interests       0
# location        0
# demographics    0
# profession      0
# income          0
# indebt          0
# isHomeOwner     0
# Owns_Car        0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   age           1000 non-null   int64
#  1   gender        1000 non-null   object
#  2   time_spent    1000 non-null   int64
#  3   platform      1000 non-null   object
#  4   interests     1000 non-null   object
#  5   location      1000 non-null   object
#  6   demographics  1000 non-null   object
#  7   profession    1000 non-null   object
#  8   income        1000 non-null   int64
#  9   indebt        1000 non-null   bool
#  10  isHomeOwner   1000 non-null   bool
#  11  Owns_Car      1000 non-null   bool
# dtypes: bool(3), int64(3), object(6)
# memory usage: 73.4+ KB

# %%
datset.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 datset.describe()
#
# NameError: name 'datset' is not defined

# %%
dataset.describe()
# Out:
#                age   time_spent        income
# count  1000.000000  1000.000000   1000.000000
# mean     40.986000     5.029000  15014.823000
# std      13.497852     2.537834   2958.628221
# min      18.000000     1.000000  10012.000000
# 25%      29.000000     3.000000  12402.250000
# 50%      42.000000     5.000000  14904.500000
# 75%      52.000000     7.000000  17674.250000
# max      64.000000     9.000000  19980.000000

# %%
dataset.corr
# Out:
# <bound method DataFrame.corr of      age      gender  time_spent   platform  interests        location  \
# 0     56        male           3  Instagram     Sports  United Kingdom
# 1     46      female           2   Facebook     Travel  United Kingdom
# 2     32        male           8  Instagram     Sports       Australia
# 3     60  non-binary           5  Instagram     Travel  United Kingdom
# 4     25        male           1  Instagram  Lifestlye       Australia
# ..   ...         ...         ...        ...        ...             ...
# 995   22      female           8  Instagram  Lifestlye  United Kingdom
# 996   40  non-binary           6    YouTube     Travel  United Kingdom
# 997   27  non-binary           5    YouTube     Travel  United Kingdom
# 998   61      female           4    YouTube     Sports       Australia
# 999   19      female           8    YouTube     Travel       Australia
#
#     demographics         profession  income  indebt  isHomeOwner  Owns_Car
# ...

# %%
fog_A = []
num_B = []
for column in dataset.columns:
    if dataset[column].nunique() > 10:
        num_B.append(column)
    else:
        fog_A.append(column)

# %% [markdown]
# num_B

# %%
fog_A
# Out:
# ['gender',
#  'time_spent',
#  'platform',
#  'interests',
#  'location',
#  'demographics',
#  'profession',
#  'indebt',
#  'isHomeOwner',
#  'Owns_Car']

# %%
dataset.columns
# Out:
# Index(['age', 'gender', 'time_spent', 'platform', 'interests', 'location',
#        'demographics', 'profession', 'income', 'indebt', 'isHomeOwner',
#        'Owns_Car'],
#       dtype='object')

# %%
dataset.nunique()
# Out:
# age              47
# gender            3
# time_spent        9
# platform          3
# interests         3
# location          3
# demographics      3
# profession        3
# income          955
# indebt            2
# isHomeOwner       2
# Owns_Car          2
# dtype: int64

# %%
sns.countplot(x='gender', data=dataset, palette=['Pink', 'skyBlue','Blue'])
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 plt.show()
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as pl

# %%
pl.show()

# %%
dataset['gender'].value_counts()
# Out:
# gender
# male          337
# non-binary    332
# female        331
# Name: count, dtype: int64

# %%
dataset['gender'].value_counts().plot(kind='pie', autopct="%1.2f%%")
# Out:
# <Axes: ylabel='count'>

# %%
dataset['gender'].unique()
# Out:
# array(['male', 'female', 'non-binary'], dtype=object)

# %%
# Histogram of gender

# %%
pl.figure(figsize=(8, 6))
sns.histplot(dataset['gender'], bins=20, kde=True, color='brown')
# Out:
# <Axes: xlabel='gender', ylabel='Count'>

# %%
pl.show()

# %%
dataset['age'].unique()
# Out:
# array([56, 46, 32, 60, 25, 38, 36, 40, 28, 41, 53, 57, 20, 39, 19, 61, 47,
#        55, 50, 29, 42, 44, 59, 45, 33, 64, 54, 24, 26, 35, 21, 31, 43, 37,
#        52, 34, 23, 51, 27, 48, 62, 58, 18, 22, 30, 49, 63], dtype=int64)

# %%
# Histogram of age

# %%
sns.scatterplot(x='age', y='gender', data=dataset)
# Out:
# <Axes: xlabel='age', ylabel='gender'>

# %%
sns.histplot(x='gender', y='age', data=dataset)
# Out:
# <Axes: xlabel='gender', ylabel='age'>

# %%
pl.figure(figsize=(10,10))
sns.violinplot(x='gender', y='age', data=dataset, color='brown')
# Out:
# <Axes: xlabel='gender', ylabel='age'>

# %%
pl.figure(figsize=(10,10))
sns.lineplot(x='gender', y='age', data=dataset, color='darkgreen')
pl.xlabel('2023, or hopeless?')
pl.ylabel('2024')
pl.show()
